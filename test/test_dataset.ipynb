# %%
from omegaconf import OmegaConf
from hydra.utils import instantiate
import sys
import os
from matplotlib import pyplot as plt
import numpy as np
import hydra
from PIL import Image
os.chdir('/root/projects/sign_language_transformer')
sys.path.append('src')
from csi_sign_language.data.datamodule.ph14 import Ph14DataModule

data_dir = 'dataset/preprocessed/ph14_lmdb'
dm = Ph14DataModule(data_dir, batch_size=1, num_workers=1, train_shuffle=True)
dataset = dm.test_set

# %%
frame = dataset[2]['video'][30]
# frame  = frame.transpose(0, 2, 3, 1)
plt.imshow(frame)

# %%
image = Image.fromarray(frame)
image.save('resources/test_image.png')
